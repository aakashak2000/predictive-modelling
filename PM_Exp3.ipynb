# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#reading the csv file and storing it in the dataframe
df = pd.read_csv("pulsar_stars.csv")
df
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# ...

# %%
df.shape
# Out:
# (17898, 9)

# %%
#checking for missing values
df.isna().sum()
# Out:
#  Mean of the integrated profile                  0
#  Standard deviation of the integrated profile    0
#  Excess kurtosis of the integrated profile       0
#  Skewness of the integrated profile              0
#  Mean of the DM-SNR curve                        0
#  Standard deviation of the DM-SNR curve          0
#  Excess kurtosis of the DM-SNR curve             0
#  Skewness of the DM-SNR curve                    0
# target_class                                     0
# dtype: int64

# %% [markdown]
# There are no missing values or null values.

# %%
#observing the balance in the dataset (whether the classes are in the ratio 1:1 or not)
df.target_class.value_counts()
# Out:
# 0    16259
# 1     1639
# Name: target_class, dtype: int64

# %% [markdown]
# This is a highly imbalanced dataset

# %%
df.dtypes
# Out:
#  Mean of the integrated profile                  float64
#  Standard deviation of the integrated profile    float64
#  Excess kurtosis of the integrated profile       float64
#  Skewness of the integrated profile              float64
#  Mean of the DM-SNR curve                        float64
#  Standard deviation of the DM-SNR curve          float64
#  Excess kurtosis of the DM-SNR curve             float64
#  Skewness of the DM-SNR curve                    float64
# target_class                                       int64
# dtype: object

# %% [markdown]
# The only categorical variable is the targer_class variable

# %%
#observing central tendencies of every column in the dataset
df.describe(include = 'all')
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
#treating outliers
#creating a mask for upper and lower bound beyond which the observations are considered outliers
#outliers are replaced with values of the lower and upper bounds accodingly
for col in df.columns:
    print("capping the ",col)
    if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
        df_mean = df[col].mean()
        df_std = df[col].std()
        cut_off = df_std * 3
        lower, upper = df_mean - cut_off, df_mean + cut_off
        df[col][df[col] < lower] = lower
        df[col][df[col] > upper] = upper
    else:
        df[col]=df[col]
# Out:
# capping the   Mean of the integrated profile
# capping the   Standard deviation of the integrated profile
# capping the   Excess kurtosis of the integrated profile
# capping the   Skewness of the integrated profile
# capping the   Mean of the DM-SNR curve
# capping the   Standard deviation of the DM-SNR curve
# capping the   Excess kurtosis of the DM-SNR curve
# capping the   Skewness of the DM-SNR curve
# capping the  target_class
# /Users/aakash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/aakash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#observing central tendencies again after treating outliers in the dataset
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.402374
# std                          24.546171
# min                          34.121162
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         188.038774
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.507962
# std                                         6.673451
# min                                        26.019963
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        67.079100
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
#visualisations
#using seaborn's pairplot which provides us with multiple scatter plots 
#that tell us the relationship of every variable in the dataset with each other 
sns.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop([" Mean of the integrated profile", "target_class"], 1)
y = df[" Mean of the integrated profile"]

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.2, random_state = 42)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaled_X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
scaled_X_test = pd.DataFrame(X_test_sclaed, columns=X_test.columns)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
y_pred = reg.predict(X_test_scaled)

# %%
mse(y_test, y_pred)
# Out:
# 771.2923186678834
